# %%
# Cell 1: Install and import (run once)
# !pip install pyodbc
# !pip install pandas
import pyodbc
import pandas as pd

# Cell 2: Create connection
conn_str = (
    "Driver={SQL Server};"
    "Server=localhost;"
    "Database=AdventureWorksLT2022;"
    "UID=sa;"
    "PWD=PaoloSid6189*;"
    "TrustServerCertificate=yes;"  # Add this if you get SSL/certificate errors
)
conn = pyodbc.connect(conn_str)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'PostgreSQL ANSI(x64)', 'PostgreSQL ANSI', 'PostgreSQL Unicode(x64)', 'PostgreSQL Unicode', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %% [markdown]
# 1. Open a query editor for your AdventureWorks database, and create a new query.

# %% [markdown]
# 2\. Type the following query to return the Name and ListPrice of all products:

# %%
query = """
SELECT * FROM SalesLT.Customer
"""

df = pd.read_sql(query, conn)
display(df)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24264\3487369116.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#      CustomerID  NameStyle Title FirstName MiddleName    LastName Suffix  \
# 0             1      False   Mr.   Orlando         N.         Gee   None
# 1             2      False   Mr.     Keith       None      Harris   None
# 2             3      False   Ms.     Donna         F.    Carreras   None
# 3             4      False   Ms.     Janet         M.       Gates   None
# 4             5      False   Mr.      Lucy       None  Harrington   None
# ..          ...        ...   ...       ...        ...         ...    ...
# 842       30113      False   Mr.      Raja         D.   Venugopal   None
# 843       30115      False   Ms.      Dora         P.      Verdad   None
# ...

# %%
# !pip install ipython-sql
# %load_ext sql
# %sql mssql+pyodbc://sa:PaoloSid6189*@localhost/AdventureWorksLT2022?driver=SQL+Server&TrustServerCertificate=yes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
SELECT Name, ListPrice
FROM SalesLT.Product;
# Out:
#   Cell In[12], line 1
#     SELECT Name, ListPrice
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 3. <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and note that the results are presented in no particular order.</span>

# %% [markdown]
# 4. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query to add an&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ORDER BY</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;clause that sorts the results by&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Name</span><span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">, as shown here:</span>

# %%
-- Active: 1763121774492@@127.0.0.1@1433@AdventureWorksLT2022
-- Active: 1763121774492@@127.0.0.1@1433@AdventureWorksLT2022@SalesLT
SELECT Name, ListPrice
FROM SalesLt.Product
ORDER BY Name;

# %% [markdown]
# 5. <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and review the results. This time the products are listed in alphabetical order by&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Name</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">.</span>

# %% [markdown]
# 6. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as shown below to sort the results by&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ListPrice</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
ORDER BY ListPrice;
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/workspaces/t-sql-learning/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# 7. <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and note that the results are listed in ascending order of&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ListPrice</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">. By default, the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ORDER BY</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">clause applies an ascending sort order to the specified field.</span>

# %% [markdown]
# 8. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as shown below to sort the results into descending order of&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ListPrice</span><span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">.</span>

# %%
-- Active: 1763122377640@@127.0.0.1@1433@AdventureWorksLT2022
-- Active: 1763122377640@@127.0.0.1@1433@AdventureWorksLT2022
SELECT Name, ListPrice
FROM SalesLT.Product
ORDER BY ListPrice DESC, Name ASC;
# Out:
#   Cell In[1], line 1
#     -- Active: 1763122377640@@127.0.0.1@1433@AdventureWorksLT2022
#     ^
# SyntaxError: illegal target for annotation

# %% [markdown]
# 9.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and note that the results now show the most expensive items first.</span>

# %% [markdown]
# 10.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as shown below to sort the results into descending order of&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ListPrice</span><span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">, and then into ascending order of&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Name</span><span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">.</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
ORDER BY ListPrice DESC, Name ASC;

# %% [markdown]
# 11.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and review the results. Note that they are sorted into descending order of&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ListPrice</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">, and each set of products with the same price is sorted in ascending order of</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Name</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">.</span>

# %% [markdown]
# ## Restrict results using TOP
#
# <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Sometimes you only want to return a specific number of rows. For example, you might want to find the twenty most expensive products.</span>

# %% [markdown]
# 1. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the existing query to return the&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Name</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;and&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ListPrice</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;of all products:</span>

# %%
SELECT TOP(20) Name, ListPrice
FROM SalesLT.Product
ORDER BY ListPrice DESC;
# Out:
#   Cell In[3], line 1
#     SELECT TOP(20) Name, ListPrice
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and note that the results contain the first twenty products in descending order of&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ListPrice</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">. Typically, you include an</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ORDER BY</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">clause when using the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">TOP</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">parameter; otherwise the query just returns the first specified number of rows in an arbitrary order.</span>

# %% [markdown]
# 3. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query to add the&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">WITH TIES</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;parameter as shown here, and re-run it.</span>

# %%
SELECT TOP(20) WITH TIES Name, ListPrice
FROM SalesLT.Product
ORDER BY ListPrice DESC;
# Out:
# (21 rows affected)
# Total execution time: 00:00:00.031
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>Road-150 Red, 62</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 44</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 48</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 52</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 56</td><td>3578,27</td></tr>
# <tr><td>Mountain-100 Silver, 38</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Silver, 42</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Silver, 44</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Silver, 48</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Black, 38</td><td>3374,99</td></tr>
# <tr><td>Mountain-100 Black, 42</td><td>3374,99</td></tr>
# <tr><td>Mountain-100 Black, 44</td><td>3374,99</td></tr>
# <tr><td>Mountain-100 Black, 48</td><td>3374,99</td></tr>
# <tr><td>Road-250 Red, 44</td><td>2443,35</td></tr>
# <tr><td>Road-250 Red, 48</td><td>2443,35</td></tr>
# ...

# %% [markdown]
# 4.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">This time, there are 21 rows in the results, because there are multiple products that share the same price, one of which wasn’t included when ties were ignored by the previous query.</span>
#
# In T-SQL, `WITH TIES` is used with the `TOP` clause to include additional rows that have the same value in the `ORDER BY` columns as the last row that would normally be returned by `TOP`.<span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;"><br></span>
#
# ## How it works
#
# Without `WITH TIES`, `TOP N` returns exactly N rows. With `WITH TIES`, you get N rows _plus_ any additional rows that "tie" with the Nth row based on the `ORDER BY` criteria.
#
# ## Important notes
#
# - You **must** include an `ORDER BY` clause when using `WITH TIES` (otherwise there's no way to determine what "ties")
# - The tie is determined by **all** columns in the `ORDER BY` clause
# - Useful for rankings, leaderboards, or when you need to include all items at a cutoff threshold

# %% [markdown]
# 5. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query to add the&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">PERCENT</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;parameter as shown here, and re-run it.</span>

# %%
SELECT TOP(20) PERCENT WITH TIES Name, ListPrice
FROM SalesLT.Product
ORDER BY ListPrice DESC;
# Out:
# (60 rows affected)
# Total execution time: 00:00:00.020
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>Road-150 Red, 62</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 44</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 48</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 52</td><td>3578,27</td></tr>
# <tr><td>Road-150 Red, 56</td><td>3578,27</td></tr>
# <tr><td>Mountain-100 Silver, 38</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Silver, 42</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Silver, 44</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Silver, 48</td><td>3399,99</td></tr>
# <tr><td>Mountain-100 Black, 38</td><td>3374,99</td></tr>
# <tr><td>Mountain-100 Black, 42</td><td>3374,99</td></tr>
# <tr><td>Mountain-100 Black, 44</td><td>3374,99</td></tr>
# <tr><td>Mountain-100 Black, 48</td><td>3374,99</td></tr>
# <tr><td>Road-250 Red, 44</td><td>2443,35</td></tr>
# <tr><td>Road-250 Red, 48</td><td>2443,35</td></tr>
# ...

# %% [markdown]
# 6.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Note that this time the results contain the 20% most expensive products.</span>

# %% [markdown]
# ## Retrieve pages of results with OFFSET and FETCH
#
# User interfaces and reports often present large volumes of data as pages, you make them easier to navigate on a screen.

# %% [markdown]
# 1. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the existing query to return product&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Name</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;and&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ListPrice</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;values:</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
ORDER BY Name OFFSET 0 ROWS FETCH NEXT 10 ROWS ONLY;
# Out:
# (10 rows affected)
# Total execution time: 00:00:00.004
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>All-Purpose Bike Stand</td><td>159,00</td></tr>
# <tr><td>AWC Logo Cap</td><td>8,99</td></tr>
# <tr><td>Bike Wash - Dissolver</td><td>7,95</td></tr>
# <tr><td>Cable Lock</td><td>25,00</td></tr>
# <tr><td>Chain</td><td>20,24</td></tr>
# <tr><td>Classic Vest, L</td><td>63,50</td></tr>
# <tr><td>Classic Vest, M</td><td>63,50</td></tr>
# <tr><td>Classic Vest, S</td><td>63,50</td></tr>
# <tr><td>Fender Set - Mountain</td><td>21,98</td></tr>
# <tr><td>Front Brakes</td><td>106,50</td></tr>
# </table>

# %% [markdown]
# 2.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and note the effect of the&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">OFFSET</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">and</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">FETCH</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">parameters of the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ORDER BY</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">clause. The results start at the 0 position (the beginning of the result set) and include only the next 10 rows, essentially defining the first page of results with 10 rows per page.</span>

# %% [markdown]
# 3. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as shown here, and run it to retrieve the next page of results.</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
ORDER BY Name OFFSET 10 ROWS FETCH NEXT 10 ROWS ONLY;
# Out:
# (10 rows affected)
# Total execution time: 00:00:00.007
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>Front Derailleur</td><td>91,49</td></tr>
# <tr><td>Full-Finger Gloves, L</td><td>37,99</td></tr>
# <tr><td>Full-Finger Gloves, M</td><td>37,99</td></tr>
# <tr><td>Full-Finger Gloves, S</td><td>37,99</td></tr>
# <tr><td>Half-Finger Gloves, L</td><td>24,49</td></tr>
# <tr><td>Half-Finger Gloves, M</td><td>24,49</td></tr>
# <tr><td>Half-Finger Gloves, S</td><td>24,49</td></tr>
# <tr><td>Headlights - Dual-Beam</td><td>34,99</td></tr>
# <tr><td>Headlights - Weatherproof</td><td>44,99</td></tr>
# <tr><td>Hitch Rack - 4-Bike</td><td>120,00</td></tr>
# </table>

# %% [markdown]
# ## Use the ALL and DISTINCT options
#
# Often, multiple rows in a table may contain the same values for a given subset of fields. For example, a table of products might contain a Color field that identifies the color of a given product. It’s not unreasonable to assume that there may be multiple products of the same color. Similarly, the table might contain a Size field; and again it’s not unreasonable to assume that there may be multiple products of the same size; or even multiple products with the same combination of size and color.

# %% [markdown]
# 1.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Start Azure Data Studio, and create a new query (you can do this from the&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">File</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">menu or on the</span> _welcome_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">page).</span>

# %% [markdown]
# 2.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">In the new&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">SQLQuery_…</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">pane, use the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Connect</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">button to connect the query to the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">AdventureWorks</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">saved connection.</span>

# %% [markdown]
# 3.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">In the query editor, enter the following code:</span>

# %%
SELECT Color
FROM SalesLT.Product;

# %% [markdown]
# 4.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Use the&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">⏵Run</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">button to run the query, and and after a few seconds, review the results, which includes the color of each product in the table.</span>

# %% [markdown]
# 5.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as follows, and re-run it.</span>

# %%
SELECT ALL Color
FROM SalesLT.Product;

# %% [markdown]
# <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">The results should be the same as before. The&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ALL</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;parameter is the default behavior, and is applied implicitly to return a row for every record that meets the query criteria.</span>

# %% [markdown]
# 6. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query to replace&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ALL</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;with&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">DISTINCT</span><span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">, as shown here:</span>

# %%
SELECT DISTINCT Color
FROM SalesLT.Product;
# Out:
# (10 rows affected)
# Total execution time: 00:00:00.024
# <table>
# <tr><th>Color</th></tr>
# <tr><td>NULL</td></tr>
# <tr><td>Black</td></tr>
# <tr><td>Blue</td></tr>
# <tr><td>Grey</td></tr>
# <tr><td>Multi</td></tr>
# <tr><td>Red</td></tr>
# <tr><td>Silver</td></tr>
# <tr><td>Silver/Black</td></tr>
# <tr><td>White</td></tr>
# <tr><td>Yellow</td></tr>
# </table>

# %% [markdown]
# 7.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the modified query and note that the results include one row for each unique&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Color</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">value. This ability to remove duplicates from the results can often be useful - for example to retrieve values in order to populate a drop-down list of color options in a user interface.</span>

# %% [markdown]
# 8.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query to add the&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Size</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;field as shown here:</span>

# %%
SELECT DISTINCT Color, Size
FROM SalesLT.Product;
# Out:
# (68 rows affected)
# Total execution time: 00:00:00.024
# <table>
# <tr><th>Color</th><th>Size</th></tr>
# <tr><td>NULL</td><td>NULL</td></tr>
# <tr><td>Black</td><td>NULL</td></tr>
# <tr><td>Black</td><td>38</td></tr>
# <tr><td>Black</td><td>40</td></tr>
# <tr><td>Black</td><td>42</td></tr>
# <tr><td>Black</td><td>44</td></tr>
# <tr><td>Black</td><td>46</td></tr>
# <tr><td>Black</td><td>48</td></tr>
# <tr><td>Black</td><td>52</td></tr>
# <tr><td>Black</td><td>58</td></tr>
# <tr><td>Black</td><td>60</td></tr>
# <tr><td>Black</td><td>62</td></tr>
# <tr><td>Black</td><td>L</td></tr>
# <tr><td>Black</td><td>M</td></tr>
# <tr><td>Black</td><td>S</td></tr>
# <tr><td>Black</td><td>XL</td></tr>
# <tr><td>Blue</td><td>NULL</td></tr>
# <tr><td>Blue</td><td>44</td></tr>
# <tr><td>Blue</td><td>46</td></tr>
# <tr><td>Blue</td><td>50</td></tr>
# <tr><td>Blue</td><td>54</td></tr>
# <tr><td>Blue</td><td>58</td></tr>
# <tr><td>Blue</td><td>60</td></tr>
# <tr><td>Blue</td><td>62</td></tr>
# ...

# %% [markdown]
# 9. <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the modified query and note that it returns each unique combination of color and size.</span>

# %% [markdown]
# ## Filter results with the WHERE clause
#
# Most queries for application development or reporting involve filtering the data to match specified criteria. You typically apply filtering criteria as a predicate in a WHERE clause of a query.

# %% [markdown]
# 1.  In Azure Data Studio, replace the existing query with the following code:

# %%
SELECT Name, Color, Size
FROM SalesLT.Product
WHERE ProductModelID = 6
ORDER BY Name;
# Out:
# (11 rows affected)
# Total execution time: 00:00:00.018
# <table>
# <tr><th>Name</th><th>Color</th><th>Size</th></tr>
# <tr><td>HL Road Frame - Black, 44</td><td>Black</td><td>44</td></tr>
# <tr><td>HL Road Frame - Black, 48</td><td>Black</td><td>48</td></tr>
# <tr><td>HL Road Frame - Black, 52</td><td>Black</td><td>52</td></tr>
# <tr><td>HL Road Frame - Black, 58</td><td>Black</td><td>58</td></tr>
# <tr><td>HL Road Frame - Black, 62</td><td>Black</td><td>62</td></tr>
# <tr><td>HL Road Frame - Red, 44</td><td>Red</td><td>44</td></tr>
# <tr><td>HL Road Frame - Red, 48</td><td>Red</td><td>48</td></tr>
# <tr><td>HL Road Frame - Red, 52</td><td>Red</td><td>52</td></tr>
# <tr><td>HL Road Frame - Red, 56</td><td>Red</td><td>56</td></tr>
# <tr><td>HL Road Frame - Red, 58</td><td>Red</td><td>58</td></tr>
# <tr><td>HL Road Frame - Red, 62</td><td>Red</td><td>62</td></tr>
# </table>

# %% [markdown]
# 2.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Run the query and review the results, which contain the&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Name</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">,</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Color</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">, and</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Size</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">for each product with a</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ProductModelID</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">value of</span> _6_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">(this is the ID for the</span> _HL Road Frame_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">product model, of which there are multiple variants).</span>

# %% [markdown]
# 3.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Replace the query with the following code, which uses the&nbsp;</span> _not equal_ <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;(&lt;&gt;) operator, and run it.</span>

# %%
SELECT Name, Color, Size
FROM SalesLT.Product
WHERE ProductModelID <> 6
ORDER BY Name;
# Out:
# (284 rows affected)
# Total execution time: 00:00:00.019
# <table>
# <tr><th>Name</th><th>Color</th><th>Size</th></tr>
# <tr><td>All-Purpose Bike Stand</td><td>NULL</td><td>NULL</td></tr>
# <tr><td>AWC Logo Cap</td><td>Multi</td><td>NULL</td></tr>
# <tr><td>Bike Wash - Dissolver</td><td>NULL</td><td>NULL</td></tr>
# <tr><td>Cable Lock</td><td>NULL</td><td>NULL</td></tr>
# <tr><td>Chain</td><td>Silver</td><td>NULL</td></tr>
# <tr><td>Classic Vest, L</td><td>Blue</td><td>L</td></tr>
# <tr><td>Classic Vest, M</td><td>Blue</td><td>M</td></tr>
# <tr><td>Classic Vest, S</td><td>Blue</td><td>S</td></tr>
# <tr><td>Fender Set - Mountain</td><td>NULL</td><td>NULL</td></tr>
# <tr><td>Front Brakes</td><td>Silver</td><td>NULL</td></tr>
# <tr><td>Front Derailleur</td><td>Silver</td><td>NULL</td></tr>
# <tr><td>Full-Finger Gloves, L</td><td>Black</td><td>L</td></tr>
# <tr><td>Full-Finger Gloves, M</td><td>Black</td><td>M</td></tr>
# <tr><td>Full-Finger Gloves, S</td><td>Black</td><td>S</td></tr>
# ...

# %% [markdown]
# 3.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Review the results, noting that they contain all products with a&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ProductModelID</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">other than</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">6</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">.</span>

# %% [markdown]
# 4.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Replace the query with the following code, and run it.</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
WHERE ListPrice > 1000.00
ORDER BY ListPrice;
# Out:
# (86 rows affected)
# Total execution time: 00:00:00.016
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>HL Touring Frame - Yellow, 60</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Yellow, 46</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Yellow, 50</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Yellow, 54</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Blue, 46</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Blue, 50</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Blue, 54</td><td>1003,91</td></tr>
# <tr><td>HL Touring Frame - Blue, 60</td><td>1003,91</td></tr>
# <tr><td>Mountain-300 Black, 38</td><td>1079,99</td></tr>
# <tr><td>Mountain-300 Black, 40</td><td>1079,99</td></tr>
# <tr><td>Mountain-300 Black, 44</td><td>1079,99</td></tr>
# <tr><td>Mountain-300 Black, 48</td><td>1079,99</td></tr>
# <tr><td>Road-550-W Yellow, 38</td><td>1120,49</td></tr>
# <tr><td>Road-550-W Yellow, 40</td><td>1120,49</td></tr>
# ...

# %% [markdown]
# 6.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Review the results, noting that they contain all products with a&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ListPrice</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">greater than 1000.00.</span>

# %% [markdown]
# 7.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as follows, and run it.</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
WHERE Name LIKE 'HL Road Frame %';
# Out:
# (11 rows affected)
# Total execution time: 00:00:00.019
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>HL Road Frame - Black, 44</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Black, 48</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Black, 52</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Black, 58</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Black, 62</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 44</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 48</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 52</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 56</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 58</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 62</td><td>1431,50</td></tr>
# </table>

# %% [markdown]
# 8.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Review the results, noting that the&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">LIKE</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">operator enables you to match string patterns. The</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">%</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">character in the predicate is a wildcard for one or more characters, so the query returns all rows where the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Name</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">is</span> _HL Road Frame_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">followed by any string.</span>
#
# <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;"><br></span>
#
# <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">The</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">LIKE</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">operator can be used to define complex pattern matches based on regular expressions, which can be useful when dealing with string data that follows a predictable pattern.</span>

# %% [markdown]
# 9.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as follows, and run it.</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
WHERE ProductNumber LIKE 'FR-_[0-9][0-9]_-[0-9][0-9]';
# Out:
# (79 rows affected)
# Total execution time: 00:00:00.006
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>HL Road Frame - Black, 58</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 58</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 62</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 44</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 48</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 52</td><td>1431,50</td></tr>
# <tr><td>HL Road Frame - Red, 56</td><td>1431,50</td></tr>
# <tr><td>LL Road Frame - Black, 58</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Black, 60</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Black, 62</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 44</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 48</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 52</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 58</td><td>337,22</td></tr>
# ...

# %% [markdown]
# 10.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Review the results. This time the results include products with a&nbsp;</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">ProductNumber</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">that matches patterns similar to FR-</span>_xNNx_<span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">-</span>_NN_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">(in which</span> _x_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">is a letter and</span> _N_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">is a numeral).</span>
#
# <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;"><br></span>
#
# <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">Tip</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">: To learn more about pattern-matching with the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">LIKE</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">operator, see the</span> [Transact-SQL documentation](https://docs.microsoft.com/sql/t-sql/language-elements/like-transact-sql)

# %% [markdown]
# 11.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Modify the query as follows, and run it.</span>

# %%
SELECT Name, ListPrice
FROM SalesLT.Product
WHERE SellEndDate IS NOT NULL;
# Out:
# (98 rows affected)
# Total execution time: 00:00:00.023
# <table>
# <tr><th>Name</th><th>ListPrice</th></tr>
# <tr><td>Mountain Bike Socks, M</td><td>9,50</td></tr>
# <tr><td>Mountain Bike Socks, L</td><td>9,50</td></tr>
# <tr><td>LL Road Frame - Red, 44</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 48</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 52</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 58</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 60</td><td>337,22</td></tr>
# <tr><td>LL Road Frame - Red, 62</td><td>337,22</td></tr>
# <tr><td>ML Road Frame - Red, 44</td><td>594,83</td></tr>
# <tr><td>ML Road Frame - Red, 48</td><td>594,83</td></tr>
# <tr><td>ML Road Frame - Red, 52</td><td>594,83</td></tr>
# <tr><td>ML Road Frame - Red, 58</td><td>594,83</td></tr>
# <tr><td>ML Road Frame - Red, 60</td><td>594,83</td></tr>
# <tr><td>HL Mountain Frame - Silver, 44</td><td>1364,50</td></tr>
# ...

# %% [markdown]
# 12.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Note that to filter based on&nbsp;</span> _NULL_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">values you must use</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">IS NULL</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">(or</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">IS NOT NULL</span><span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">) you cannot compare a</span> _NULL_ <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">value using the</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; box-sizing: border-box; font-weight: bolder;">=</span> <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">operator.</span>

# %% [markdown]
# 13. <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Now try the following query, which uses the&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">BETWEEN</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;operator to define a filter based on values within a defined range.</span>

# %%
SELECT Name
FROM SalesLT.Product
WHERE SellEndDate BETWEEN '2006/1/1' AND '2006/12/31';
# Out:
# (29 rows affected)
# Total execution time: 00:00:00.018
# <table>
# <tr><th>Name</th></tr>
# <tr><td>Mountain Bike Socks, M</td></tr>
# <tr><td>Mountain Bike Socks, L</td></tr>
# <tr><td>ML Road Frame - Red, 44</td></tr>
# <tr><td>ML Road Frame - Red, 48</td></tr>
# <tr><td>ML Road Frame - Red, 52</td></tr>
# <tr><td>ML Road Frame - Red, 58</td></tr>
# <tr><td>ML Road Frame - Red, 60</td></tr>
# <tr><td>HL Mountain Frame - Silver, 44</td></tr>
# <tr><td>HL Mountain Frame - Silver, 48</td></tr>
# <tr><td>HL Mountain Frame - Black, 44</td></tr>
# <tr><td>HL Mountain Frame - Black, 48</td></tr>
# <tr><td>Road-150 Red, 62</td></tr>
# <tr><td>Road-150 Red, 44</td></tr>
# <tr><td>Road-150 Red, 48</td></tr>
# <tr><td>Road-150 Red, 52</td></tr>
# <tr><td>Road-150 Red, 56</td></tr>
# <tr><td>Road-450 Red, 58</td></tr>
# <tr><td>Road-450 Red, 60</td></tr>
# <tr><td>Road-450 Red, 44</td></tr>
# <tr><td>Road-450 Red, 48</td></tr>
# <tr><td>Road-450 Red, 52</td></tr>
# ...

# %% [markdown]
# 14.  <span style="background-color: rgb(255, 255, 255); color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px;">Review the results, which contain products that the company stopped selling in 2006.</span>

# %% [markdown]
# 15.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Run the following query, which retrieves products with a&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">ProductCategoryID</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;value that is in a specified list.</span>

# %%
SELECT ProductCategoryID, Name, ListPrice
FROM SalesLT.Product
WHERE ProductCategoryID IN (5,6,7);
# Out:
# (97 rows affected)
# Total execution time: 00:00:00.018
# <table>
# <tr><th>ProductCategoryID</th><th>Name</th><th>ListPrice</th></tr>
# <tr><td>6</td><td>Road-150 Red, 62</td><td>3578,27</td></tr>
# <tr><td>6</td><td>Road-150 Red, 44</td><td>3578,27</td></tr>
# <tr><td>6</td><td>Road-150 Red, 48</td><td>3578,27</td></tr>
# <tr><td>6</td><td>Road-150 Red, 52</td><td>3578,27</td></tr>
# <tr><td>6</td><td>Road-150 Red, 56</td><td>3578,27</td></tr>
# <tr><td>6</td><td>Road-450 Red, 58</td><td>1457,99</td></tr>
# <tr><td>6</td><td>Road-450 Red, 60</td><td>1457,99</td></tr>
# <tr><td>6</td><td>Road-450 Red, 44</td><td>1457,99</td></tr>
# <tr><td>6</td><td>Road-450 Red, 48</td><td>1457,99</td></tr>
# <tr><td>6</td><td>Road-450 Red, 52</td><td>1457,99</td></tr>
# <tr><td>6</td><td>Road-650 Red, 58</td><td>782,99</td></tr>
# <tr><td>6</td><td>Road-650 Red, 60</td><td>782,99</td></tr>
# <tr><td>6</td><td>Road-650 Red, 62</td><td>782,99</td></tr>
# ...

# %% [markdown]
# 16.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Now try the following query, which uses the&nbsp;</span> <span style="box-sizing: border-box; font-weight: bolder; color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">AND</span> <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;operator to combine two criteria.</span>

# %%
SELECT Name, ProductCategoryID, ProductNumber
FROM SalesLT.Product
WHERE ProductCategoryID IN (5,6,7) AND SellEndDate IS NULL;

# %% [markdown]
# 17.  <span style="color: rgb(34, 34, 34); font-family: segoe-ui_normal, &quot;Segoe UI&quot;, Segoe, &quot;Segoe WP&quot;, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Try the following query, which filters the results to include rows that match one (or both) of two criteria.</span>

# %%
SELECT Name, ProductCategoryID, ProductNumber
FROM SalesLT.Product
WHERE ProductNumber LIKE 'FR%' OR ProductCategoryID IN (5,6,7);

# %% [markdown]
# ## Challenges
#
# Now that you’ve seen some examples of filtering and sorting data, it’s your chance to put what you’ve learned into practice.

# %% [markdown]
# ### Challenge 1: Retrieve data for transportation reports
#
# The logistics manager at Adventure Works has asked you to generate some reports containing details of the company’s customers to help to reduce transportation costs.
#
# 1. Retrieve a list of cities
#     - Initially, you need to produce a list of all of you customers’ locations. Write a Transact-SQL query that queries the SalesLT.Address table and retrieves the values for City and StateProvince, removing duplicates and sorted in ascending order of city.
# 2. Retrieve the heaviest products
#     - Transportation costs are increasing and you need to identify the heaviest products. Retrieve the names of the top ten percent of products by weight.

# %%
-- 1
SELECT DISTINCT City, StateProvince
FROM SalesLT.Address
ORDER BY City;

# %%
-- 2
SELECT TOP(10) Name
FROM SalesLT.Product
ORDER BY Size DESC;

-- Correct
SELECT TOP(10) PERCENT WITH TIES Name
FROM SalesLT.Product
ORDER BY Weight DESC;
# Out:
# (10 rows affected)
# (30 rows affected)
# Total execution time: 00:00:00.028
# <table>
# <tr><th>Name</th></tr>
# <tr><td>Long-Sleeve Logo Jersey, XL</td></tr>
# <tr><td>Men&#39;s Sports Shorts, XL</td></tr>
# <tr><td>Short-Sleeve Classic Jersey, XL</td></tr>
# <tr><td>Long-Sleeve Logo Jersey, S</td></tr>
# <tr><td>Men&#39;s Sports Shorts, S</td></tr>
# <tr><td>Women&#39;s Tights, S</td></tr>
# <tr><td>Men&#39;s Bib-Shorts, S</td></tr>
# <tr><td>Half-Finger Gloves, S</td></tr>
# <tr><td>Full-Finger Gloves, S</td></tr>
# <tr><td>Classic Vest, S</td></tr>
# </table>
# <table>
# <tr><th>Name</th></tr>
# <tr><td>Touring-3000 Blue, 62</td></tr>
# <tr><td>Touring-3000 Yellow, 62</td></tr>
# <tr><td>Touring-3000 Blue, 58</td></tr>
# <tr><td>Touring-3000 Yellow, 58</td></tr>
# <tr><td>Touring-3000 Blue, 54</td></tr>
# <tr><td>Touring-3000 Yellow, 54</td></tr>
# <tr><td>Touring-3000 Yellow, 50</td></tr>
# <tr><td>Touring-3000 Blue, 50</td></tr>
# <tr><td>Touring-3000 Blue, 44</td></tr>
# ...

# %% [markdown]
# ### Challenge 2: Retrieve product data
#
# The Production Manager at Adventure Works would like you to create some reports listing details of the products that you sell.
#
# 1. Retrieve product details for product model 1
#     - Initially, you need to find the names, colors, and sizes of the products with a product model ID 1.
# 2. Filter products by color and size
#     - Retrieve the product number and name of the products that have a color of _black_, _red_, or _white_ and a size of _S_ or _M_.
# 3. Filter products by product number
#     - Retrieve the product number, name, and list price of products whose product number begins _BK-_
# 4. Retrieve specific products by product number
#     - Modify your previous query to retrieve the product number, name, and list price of products whose product number begins _BK-_ followed by any character other than _R_, and ends with a _\-_ followed by any two numerals.

# %%
-- 1
SELECT Name, Color, [Size]
FROM SalesLT.Product
WHERE ProductModelID = 1;
# Out:
# (3 rows affected)
# Total execution time: 00:00:00.020
# <table>
# <tr><th>Name</th><th>Color</th><th>Size</th></tr>
# <tr><td>Classic Vest, S</td><td>Blue</td><td>S</td></tr>
# <tr><td>Classic Vest, M</td><td>Blue</td><td>M</td></tr>
# <tr><td>Classic Vest, L</td><td>Blue</td><td>L</td></tr>
# </table>

# %%
-- 2
SELECT ProductNumber, Name
FROM SalesLT.Product
WHERE Color IN ('black', 'red', 'white') AND [Size] IN ('S', 'M')
# Out:
# (12 rows affected)
# Total execution time: 00:00:00.016
# <table>
# <tr><th>ProductNumber</th><th>Name</th></tr>
# <tr><td>SO-B909-M</td><td>Mountain Bike Socks, M</td></tr>
# <tr><td>SH-M897-S</td><td>Men&#39;s Sports Shorts, S</td></tr>
# <tr><td>SH-M897-M</td><td>Men&#39;s Sports Shorts, M</td></tr>
# <tr><td>TG-W091-S</td><td>Women&#39;s Tights, S</td></tr>
# <tr><td>TG-W091-M</td><td>Women&#39;s Tights, M</td></tr>
# <tr><td>GL-H102-S</td><td>Half-Finger Gloves, S</td></tr>
# <tr><td>GL-H102-M</td><td>Half-Finger Gloves, M</td></tr>
# <tr><td>GL-F110-S</td><td>Full-Finger Gloves, S</td></tr>
# <tr><td>GL-F110-M</td><td>Full-Finger Gloves, M</td></tr>
# <tr><td>SH-W890-S</td><td>Women&#39;s Mountain Shorts, S</td></tr>
# <tr><td>SH-W890-M</td><td>Women&#39;s Mountain Shorts, M</td></tr>
# <tr><td>SO-R809-M</td><td>Racing Socks, M</td></tr>
# </table>

# %%
-- 3
SELECT ProductNumber, Name, ListPrice
FROM SalesLT.Product
WHERE ProductNumber LIKE 'BK-%';
# Out:
# (97 rows affected)
# Total execution time: 00:00:00.009
# <table>
# <tr><th>ProductNumber</th><th>Name</th><th>ListPrice</th></tr>
# <tr><td>BK-R93R-62</td><td>Road-150 Red, 62</td><td>3578,27</td></tr>
# <tr><td>BK-R93R-44</td><td>Road-150 Red, 44</td><td>3578,27</td></tr>
# <tr><td>BK-R93R-48</td><td>Road-150 Red, 48</td><td>3578,27</td></tr>
# <tr><td>BK-R93R-52</td><td>Road-150 Red, 52</td><td>3578,27</td></tr>
# <tr><td>BK-R93R-56</td><td>Road-150 Red, 56</td><td>3578,27</td></tr>
# <tr><td>BK-R68R-58</td><td>Road-450 Red, 58</td><td>1457,99</td></tr>
# <tr><td>BK-R68R-60</td><td>Road-450 Red, 60</td><td>1457,99</td></tr>
# <tr><td>BK-R68R-44</td><td>Road-450 Red, 44</td><td>1457,99</td></tr>
# <tr><td>BK-R68R-48</td><td>Road-450 Red, 48</td><td>1457,99</td></tr>
# <tr><td>BK-R68R-52</td><td>Road-450 Red, 52</td><td>1457,99</td></tr>
# <tr><td>BK-R50R-58</td><td>Road-650 Red, 58</td><td>782,99</td></tr>
# <tr><td>BK-R50R-60</td><td>Road-650 Red, 60</td><td>782,99</td></tr>
# ...

# %%
-- 4
SELECT ProductNumber, Name, ListPrice
FROM SalesLT.Product
WHERE ProductNumber LIKE 'BK-[^R]%-[0-9][0-9]';
# Out:
# (54 rows affected)
# Total execution time: 00:00:00.018
# <table>
# <tr><th>ProductNumber</th><th>Name</th><th>ListPrice</th></tr>
# <tr><td>BK-M82S-38</td><td>Mountain-100 Silver, 38</td><td>3399,99</td></tr>
# <tr><td>BK-M82S-42</td><td>Mountain-100 Silver, 42</td><td>3399,99</td></tr>
# <tr><td>BK-M82S-44</td><td>Mountain-100 Silver, 44</td><td>3399,99</td></tr>
# <tr><td>BK-M82S-48</td><td>Mountain-100 Silver, 48</td><td>3399,99</td></tr>
# <tr><td>BK-M82B-38</td><td>Mountain-100 Black, 38</td><td>3374,99</td></tr>
# <tr><td>BK-M82B-42</td><td>Mountain-100 Black, 42</td><td>3374,99</td></tr>
# <tr><td>BK-M82B-44</td><td>Mountain-100 Black, 44</td><td>3374,99</td></tr>
# <tr><td>BK-M82B-48</td><td>Mountain-100 Black, 48</td><td>3374,99</td></tr>
# <tr><td>BK-M68S-38</td><td>Mountain-200 Silver, 38</td><td>2319,99</td></tr>
# <tr><td>BK-M68S-42</td><td>Mountain-200 Silver, 42</td><td>2319,99</td></tr>
# <tr><td>BK-M68S-46</td><td>Mountain-200 Silver, 46</td><td>2319,99</td></tr>
# ...
